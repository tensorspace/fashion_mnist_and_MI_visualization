# %%
# %load_ext autoreload
# %autoreload 2
from __future__ import print_function
import os, cPickle
from collections import defaultdict, OrderedDict

import numpy as np
import keras.backend as K

import kde
import simplebinmi

import utils
trn, tst = utils.get_fashion_mnist()

# Which measure to plot
infoplane_measure = 'upper'
#infoplane_measure = 'bin'

DO_SAVE        = False    # Whether to save plots or just show them
DO_LOWER       = True    # (infoplane_measure == 'lower')   # Whether to compute lower bounds also
DO_BINNED      = True    #(infoplane_measure == 'bin')     # Whether to compute MI estimates based on binning

# MAX_EPOCHS = 10000      # Max number of epoch for which to compute mutual information measure
MAX_EPOCHS = 1000
COLORBAR_MAX_EPOCHS = 1000

# Directories from which to load saved layer activity
ARCH = '1024-20-20-20'
#ARCH = '20-20-20-20-20-20'
#ARCH = '32-28-24-20-16-12'
#ARCH = '32-28-24-20-16-12-8-8'
DIR_TEMPLATE = '%%s_%s'%ARCH

# Functions to return upper and lower bounds on entropy of layer activity
noise_variance = 1e-1                    # Added Gaussian noise variance
Klayer_activity = K.placeholder(ndim=2)  # Keras placeholder 
entropy_func_upper = K.function([Klayer_activity,], [kde.entropy_estimator_kl(Klayer_activity, noise_variance),])
entropy_func_lower = K.function([Klayer_activity,], [kde.entropy_estimator_bd(Klayer_activity, noise_variance),])


# nats to bits conversion factor
nats2bits = 1.0/np.log(2) 


# Save indexes of tests data for each of the output classes
saved_labelixs = {}
for i in range(10):
    saved_labelixs[i] = tst.y == i

labelprobs = np.mean(tst.Y, axis=0)
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #2
#   (fname, cnt))
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/matplotlib/__init__.py:962: UserWarning: Duplicate key in file "/home/ubuntu/.config/matplotlib/matplotlibrc", line #3
#   (fname, cnt))

# %%
PLOT_LAYERS    = None     # Which layers to plot.  If None, all saved layers are plotted 

# Data structure used to store results
measures = OrderedDict()
measures['relu'] = {}
measures['tanh'] = {}

# %% [markdown]
# Compute MI measures
# -----

# %%
for activation in measures.keys():
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        print("Directory %s not found" % cur_dir)
        continue
        
    # Load files saved during each epoch, and compute MI measures of the activity in that epoch
    print('*** Doing %s ***' % cur_dir)
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        fname = cur_dir + "/" + epochfile
        with open(fname, 'rb') as f:
            d = cPickle.load(f)

        epoch = d['epoch']
        if epoch in measures[activation]: # Skip this epoch if its already been processed
            continue                      # this is a trick to allow us to rerun this cell multiple times)
            
        if epoch > MAX_EPOCHS:
            continue

        print("Doing", fname)
        
        num_layers = len(d['data']['activity_tst'])

        if PLOT_LAYERS is None:
            PLOT_LAYERS = []
            for lndx in range(num_layers):
                #if d['data']['activity_tst'][lndx].shape[1] < 200 and lndx != num_layers - 1:
                PLOT_LAYERS.append(lndx)
                
        cepochdata = defaultdict(list)
        for lndx in range(num_layers):
            activity = d['data']['activity_tst'][lndx]

            # Compute marginal entropies
            h_upper = entropy_func_upper([activity,])[0]
            if DO_LOWER:
                h_lower = entropy_func_lower([activity,])[0]
                
            # Layer activity given input. This is simply the entropy of the Gaussian noise
            hM_given_X = kde.kde_condentropy(activity, noise_variance)

            # Compute conditional entropies of layer activity given output
            hM_given_Y_upper=0.
            for i in range(10):
                hcond_upper = entropy_func_upper([activity[saved_labelixs[i],:],])[0]
                hM_given_Y_upper += labelprobs[i] * hcond_upper
                
            if DO_LOWER:
                hM_given_Y_lower=0.
                for i in range(10):
                    hcond_lower = entropy_func_lower([activity[saved_labelixs[i],:],])[0]
                    hM_given_Y_lower += labelprobs[i] * hcond_lower
                    
                    
            # # It's also possible to treat the last layer probabilistically. Here is the 
            # # code to do so. Should only be applied when lndx == num_layers - 1

            # ps = activity.mean(axis=0)
            # h_lower = h_upper = sum([-p*np.log(p) for p in ps if p != 0])

            # x = -activity * np.log(activity)
            # x[activity == 0] = 0.
            # hM_given_X = np.mean(x.sum(axis=1))

            # hM_given_Y=0.
            # for i in range(10):
            #     ixs = tst.y[::subsample] == i
            #     ps = activity[ixs,:].mean(axis=0)
            #     hcond = sum([-p*np.log(p) for p in ps if p != 0])
            #     prob = np.mean(ixs)
            #     hM_given_Y += l * hcond
            # hM_given_Y_lower = hM_given_Y_upper = hM_given_Y
            # del hM_given_Y
                
            cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
            cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
            cepochdata['H_M_upper'  ].append( nats2bits * h_upper )

            pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1])
            if DO_LOWER:  # Compute lower bounds
                cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

            if DO_BINNED: # Compute binner estimates
                binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, 0.5)
                cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                cepochdata['MI_YM_bin'].append( nats2bits * binym )
                pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])
            
            print('- Layer %d %s' % (lndx, pstr) )

        measures[activation][epoch] = cepochdata
# Out:
# Directory rawdata/relu_1024-20-20-20 not found
# *** Doing rawdata/tanh_1024-20-20-20 ***
# Doing rawdata/tanh_1024-20-20-20/epoch00000000
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=9.779, MI(Y;M)=2.664 | lower: MI(X;M)=4.863, MI(Y;M)=1.946 | bin: MI(X;M)=13.101, MI(Y;M)=3.292
# - Layer 2 upper: MI(X;M)=8.504, MI(Y;M)=2.490 | lower: MI(X;M)=4.464, MI(Y;M)=1.946 | bin: MI(X;M)=12.653, MI(Y;M)=3.200
# - Layer 3 upper: MI(X;M)=7.513, MI(Y;M)=2.355 | lower: MI(X;M)=4.166, MI(Y;M)=1.899 | bin: MI(X;M)=12.026, MI(Y;M)=3.048
# - Layer 4 upper: MI(X;M)=0.382, MI(Y;M)=0.257 | lower: MI(X;M)=0.099, MI(Y;M)=0.067 | bin: MI(X;M)=-0.000, MI(Y;M)=-0.000
# Doing rawdata/tanh_1024-20-20-20/epoch00000001
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.032, MI(Y;M)=2.768 | lower: MI(X;M)=5.343, MI(Y;M)=2.165 | bin: MI(X;M)=13.033, MI(Y;M)=3.281
# - Layer 2 upper: MI(X;M)=8.733, MI(Y;M)=2.606 | lower: MI(X;M)=4.895, MI(Y;M)=2.148 | bin: MI(X;M)=12.509, MI(Y;M)=3.192
# - Layer 3 upper: MI(X;M)=7.714, MI(Y;M)=2.482 | lower: MI(X;M)=4.528, MI(Y;M)=2.090 | bin: MI(X;M)=11.745, MI(Y;M)=3.041
# - Layer 4 upper: MI(X;M)=0.671, MI(Y;M)=0.469 | lower: MI(X;M)=0.179, MI(Y;M)=0.126 | bin: MI(X;M)=-0.000, MI(Y;M)=-0.000
# Doing rawdata/tanh_1024-20-20-20/epoch00000002
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.161, MI(Y;M)=2.820 | lower: MI(X;M)=5.603, MI(Y;M)=2.267 | bin: MI(X;M)=12.979, MI(Y;M)=3.269
# - Layer 2 upper: MI(X;M)=8.849, MI(Y;M)=2.665 | lower: MI(X;M)=5.115, MI(Y;M)=2.245 | bin: MI(X;M)=12.484, MI(Y;M)=3.202
# - Layer 3 upper: MI(X;M)=7.842, MI(Y;M)=2.548 | lower: MI(X;M)=4.723, MI(Y;M)=2.186 | bin: MI(X;M)=11.677, MI(Y;M)=3.038
# - Layer 4 upper: MI(X;M)=0.951, MI(Y;M)=0.679 | lower: MI(X;M)=0.260, MI(Y;M)=0.187 | bin: MI(X;M)=0.030, MI(Y;M)=0.008
# Doing rawdata/tanh_1024-20-20-20/epoch00000003
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.243, MI(Y;M)=2.854 | lower: MI(X;M)=5.772, MI(Y;M)=2.329 | bin: MI(X;M)=12.949, MI(Y;M)=3.274
# - Layer 2 upper: MI(X;M)=8.918, MI(Y;M)=2.703 | lower: MI(X;M)=5.249, MI(Y;M)=2.307 | bin: MI(X;M)=12.461, MI(Y;M)=3.191
# - Layer 3 upper: MI(X;M)=7.930, MI(Y;M)=2.591 | lower: MI(X;M)=4.851, MI(Y;M)=2.251 | bin: MI(X;M)=11.625, MI(Y;M)=3.042
# - Layer 4 upper: MI(X;M)=1.222, MI(Y;M)=0.885 | lower: MI(X;M)=0.342, MI(Y;M)=0.251 | bin: MI(X;M)=0.263, MI(Y;M)=0.108
# Doing rawdata/tanh_1024-20-20-20/epoch00000004
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.303, MI(Y;M)=2.880 | lower: MI(X;M)=5.894, MI(Y;M)=2.372 | bin: MI(X;M)=12.913, MI(Y;M)=3.273
# - Layer 2 upper: MI(X;M)=8.972, MI(Y;M)=2.732 | lower: MI(X;M)=5.345, MI(Y;M)=2.350 | bin: MI(X;M)=12.430, MI(Y;M)=3.192
# - Layer 3 upper: MI(X;M)=8.003, MI(Y;M)=2.624 | lower: MI(X;M)=4.947, MI(Y;M)=2.300 | bin: MI(X;M)=11.579, MI(Y;M)=3.051
# - Layer 4 upper: MI(X;M)=1.488, MI(Y;M)=1.089 | lower: MI(X;M)=0.428, MI(Y;M)=0.318 | bin: MI(X;M)=0.784, MI(Y;M)=0.397
# Doing rawdata/tanh_1024-20-20-20/epoch00000005
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.344, MI(Y;M)=2.899 | lower: MI(X;M)=5.984, MI(Y;M)=2.403 | bin: MI(X;M)=12.886, MI(Y;M)=3.273
# - Layer 2 upper: MI(X;M)=9.011, MI(Y;M)=2.754 | lower: MI(X;M)=5.419, MI(Y;M)=2.382 | bin: MI(X;M)=12.361, MI(Y;M)=3.179
# - Layer 3 upper: MI(X;M)=8.062, MI(Y;M)=2.649 | lower: MI(X;M)=5.024, MI(Y;M)=2.336 | bin: MI(X;M)=11.560, MI(Y;M)=3.076
# - Layer 4 upper: MI(X;M)=1.736, MI(Y;M)=1.280 | lower: MI(X;M)=0.514, MI(Y;M)=0.386 | bin: MI(X;M)=1.409, MI(Y;M)=0.787
# Doing rawdata/tanh_1024-20-20-20/epoch00000006
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.383, MI(Y;M)=2.916 | lower: MI(X;M)=6.062, MI(Y;M)=2.429 | bin: MI(X;M)=12.862, MI(Y;M)=3.273
# - Layer 2 upper: MI(X;M)=9.049, MI(Y;M)=2.773 | lower: MI(X;M)=5.481, MI(Y;M)=2.408 | bin: MI(X;M)=12.316, MI(Y;M)=3.182
# - Layer 3 upper: MI(X;M)=8.118, MI(Y;M)=2.671 | lower: MI(X;M)=5.091, MI(Y;M)=2.366 | bin: MI(X;M)=11.551, MI(Y;M)=3.088
# - Layer 4 upper: MI(X;M)=1.965, MI(Y;M)=1.456 | lower: MI(X;M)=0.601, MI(Y;M)=0.455 | bin: MI(X;M)=1.958, MI(Y;M)=1.195
# Doing rawdata/tanh_1024-20-20-20/epoch00000007
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.412, MI(Y;M)=2.931 | lower: MI(X;M)=6.124, MI(Y;M)=2.450 | bin: MI(X;M)=12.844, MI(Y;M)=3.272
# - Layer 2 upper: MI(X;M)=9.075, MI(Y;M)=2.791 | lower: MI(X;M)=5.530, MI(Y;M)=2.429 | bin: MI(X;M)=12.281, MI(Y;M)=3.180
# - Layer 3 upper: MI(X;M)=8.163, MI(Y;M)=2.692 | lower: MI(X;M)=5.147, MI(Y;M)=2.391 | bin: MI(X;M)=11.583, MI(Y;M)=3.103
# - Layer 4 upper: MI(X;M)=2.172, MI(Y;M)=1.613 | lower: MI(X;M)=0.688, MI(Y;M)=0.524 | bin: MI(X;M)=2.273, MI(Y;M)=1.438
# Doing rawdata/tanh_1024-20-20-20/epoch00000008
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.426, MI(Y;M)=2.941 | lower: MI(X;M)=6.170, MI(Y;M)=2.467 | bin: MI(X;M)=12.829, MI(Y;M)=3.265
# - Layer 2 upper: MI(X;M)=9.085, MI(Y;M)=2.802 | lower: MI(X;M)=5.563, MI(Y;M)=2.446 | bin: MI(X;M)=12.247, MI(Y;M)=3.184
# - Layer 3 upper: MI(X;M)=8.192, MI(Y;M)=2.706 | lower: MI(X;M)=5.187, MI(Y;M)=2.410 | bin: MI(X;M)=11.565, MI(Y;M)=3.097
# - Layer 4 upper: MI(X;M)=2.329, MI(Y;M)=1.734 | lower: MI(X;M)=0.763, MI(Y;M)=0.586 | bin: MI(X;M)=2.432, MI(Y;M)=1.585
# Doing rawdata/tanh_1024-20-20-20/epoch00000009
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.454, MI(Y;M)=2.954 | lower: MI(X;M)=6.218, MI(Y;M)=2.482 | bin: MI(X;M)=12.821, MI(Y;M)=3.266
# - Layer 2 upper: MI(X;M)=9.119, MI(Y;M)=2.819 | lower: MI(X;M)=5.607, MI(Y;M)=2.464 | bin: MI(X;M)=12.226, MI(Y;M)=3.192
# - Layer 3 upper: MI(X;M)=8.244, MI(Y;M)=2.725 | lower: MI(X;M)=5.240, MI(Y;M)=2.430 | bin: MI(X;M)=11.540, MI(Y;M)=3.106
# - Layer 4 upper: MI(X;M)=2.478, MI(Y;M)=1.842 | lower: MI(X;M)=0.840, MI(Y;M)=0.649 | bin: MI(X;M)=2.571, MI(Y;M)=1.702
# Doing rawdata/tanh_1024-20-20-20/epoch00000010
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.485, MI(Y;M)=2.966 | lower: MI(X;M)=6.263, MI(Y;M)=2.497 | bin: MI(X;M)=12.826, MI(Y;M)=3.269
# - Layer 2 upper: MI(X;M)=9.153, MI(Y;M)=2.833 | lower: MI(X;M)=5.649, MI(Y;M)=2.479 | bin: MI(X;M)=12.208, MI(Y;M)=3.198
# - Layer 3 upper: MI(X;M)=8.289, MI(Y;M)=2.742 | lower: MI(X;M)=5.286, MI(Y;M)=2.448 | bin: MI(X;M)=11.503, MI(Y;M)=3.111
# - Layer 4 upper: MI(X;M)=2.602, MI(Y;M)=1.931 | lower: MI(X;M)=0.913, MI(Y;M)=0.708 | bin: MI(X;M)=2.685, MI(Y;M)=1.785
# Doing rawdata/tanh_1024-20-20-20/epoch00000011
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.497, MI(Y;M)=2.972 | lower: MI(X;M)=6.292, MI(Y;M)=2.508 | bin: MI(X;M)=12.808, MI(Y;M)=3.263
# - Layer 2 upper: MI(X;M)=9.167, MI(Y;M)=2.841 | lower: MI(X;M)=5.674, MI(Y;M)=2.492 | bin: MI(X;M)=12.190, MI(Y;M)=3.190
# - Layer 3 upper: MI(X;M)=8.312, MI(Y;M)=2.751 | lower: MI(X;M)=5.315, MI(Y;M)=2.462 | bin: MI(X;M)=11.450, MI(Y;M)=3.111
# - Layer 4 upper: MI(X;M)=2.687, MI(Y;M)=1.994 | lower: MI(X;M)=0.969, MI(Y;M)=0.755 | bin: MI(X;M)=2.742, MI(Y;M)=1.832
# Doing rawdata/tanh_1024-20-20-20/epoch00000012
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.518, MI(Y;M)=2.982 | lower: MI(X;M)=6.325, MI(Y;M)=2.520 | bin: MI(X;M)=12.784, MI(Y;M)=3.264
# - Layer 2 upper: MI(X;M)=9.189, MI(Y;M)=2.853 | lower: MI(X;M)=5.703, MI(Y;M)=2.505 | bin: MI(X;M)=12.186, MI(Y;M)=3.200
# - Layer 3 upper: MI(X;M)=8.353, MI(Y;M)=2.767 | lower: MI(X;M)=5.355, MI(Y;M)=2.478 | bin: MI(X;M)=11.420, MI(Y;M)=3.115
# - Layer 4 upper: MI(X;M)=2.777, MI(Y;M)=2.056 | lower: MI(X;M)=1.031, MI(Y;M)=0.806 | bin: MI(X;M)=2.849, MI(Y;M)=1.894
# Doing rawdata/tanh_1024-20-20-20/epoch00000013
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.535, MI(Y;M)=2.989 | lower: MI(X;M)=6.351, MI(Y;M)=2.530 | bin: MI(X;M)=12.777, MI(Y;M)=3.263
# - Layer 2 upper: MI(X;M)=9.209, MI(Y;M)=2.861 | lower: MI(X;M)=5.727, MI(Y;M)=2.517 | bin: MI(X;M)=12.190, MI(Y;M)=3.200
# - Layer 3 upper: MI(X;M)=8.380, MI(Y;M)=2.777 | lower: MI(X;M)=5.384, MI(Y;M)=2.491 | bin: MI(X;M)=11.391, MI(Y;M)=3.118
# - Layer 4 upper: MI(X;M)=2.843, MI(Y;M)=2.102 | lower: MI(X;M)=1.082, MI(Y;M)=0.848 | bin: MI(X;M)=2.917, MI(Y;M)=1.943
# Doing rawdata/tanh_1024-20-20-20/epoch00000014
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.562, MI(Y;M)=2.998 | lower: MI(X;M)=6.383, MI(Y;M)=2.541 | bin: MI(X;M)=12.773, MI(Y;M)=3.269
# - Layer 2 upper: MI(X;M)=9.242, MI(Y;M)=2.872 | lower: MI(X;M)=5.760, MI(Y;M)=2.528 | bin: MI(X;M)=12.192, MI(Y;M)=3.206
# - Layer 3 upper: MI(X;M)=8.424, MI(Y;M)=2.790 | lower: MI(X;M)=5.422, MI(Y;M)=2.505 | bin: MI(X;M)=11.404, MI(Y;M)=3.123
# - Layer 4 upper: MI(X;M)=2.906, MI(Y;M)=2.144 | lower: MI(X;M)=1.132, MI(Y;M)=0.889 | bin: MI(X;M)=2.979, MI(Y;M)=1.984
# Doing rawdata/tanh_1024-20-20-20/epoch00000015
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.584, MI(Y;M)=3.005 | lower: MI(X;M)=6.408, MI(Y;M)=2.550 | bin: MI(X;M)=12.770, MI(Y;M)=3.270
# - Layer 2 upper: MI(X;M)=9.269, MI(Y;M)=2.880 | lower: MI(X;M)=5.786, MI(Y;M)=2.539 | bin: MI(X;M)=12.193, MI(Y;M)=3.208
# - Layer 3 upper: MI(X;M)=8.456, MI(Y;M)=2.800 | lower: MI(X;M)=5.452, MI(Y;M)=2.517 | bin: MI(X;M)=11.407, MI(Y;M)=3.130
# - Layer 4 upper: MI(X;M)=2.957, MI(Y;M)=2.179 | lower: MI(X;M)=1.175, MI(Y;M)=0.925 | bin: MI(X;M)=3.020, MI(Y;M)=2.023
# Doing rawdata/tanh_1024-20-20-20/epoch00000016
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.598, MI(Y;M)=3.011 | lower: MI(X;M)=6.428, MI(Y;M)=2.558 | bin: MI(X;M)=12.759, MI(Y;M)=3.267
# - Layer 2 upper: MI(X;M)=9.287, MI(Y;M)=2.887 | lower: MI(X;M)=5.805, MI(Y;M)=2.548 | bin: MI(X;M)=12.196, MI(Y;M)=3.208
# - Layer 3 upper: MI(X;M)=8.485, MI(Y;M)=2.809 | lower: MI(X;M)=5.478, MI(Y;M)=2.528 | bin: MI(X;M)=11.395, MI(Y;M)=3.130
# - Layer 4 upper: MI(X;M)=2.999, MI(Y;M)=2.208 | lower: MI(X;M)=1.214, MI(Y;M)=0.958 | bin: MI(X;M)=3.055, MI(Y;M)=2.054
# Doing rawdata/tanh_1024-20-20-20/epoch00000017
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.626, MI(Y;M)=3.019 | lower: MI(X;M)=6.455, MI(Y;M)=2.567 | bin: MI(X;M)=12.766, MI(Y;M)=3.268
# - Layer 2 upper: MI(X;M)=9.320, MI(Y;M)=2.897 | lower: MI(X;M)=5.833, MI(Y;M)=2.559 | bin: MI(X;M)=12.221, MI(Y;M)=3.213
# - Layer 3 upper: MI(X;M)=8.522, MI(Y;M)=2.821 | lower: MI(X;M)=5.510, MI(Y;M)=2.540 | bin: MI(X;M)=11.430, MI(Y;M)=3.133
# - Layer 4 upper: MI(X;M)=3.046, MI(Y;M)=2.238 | lower: MI(X;M)=1.256, MI(Y;M)=0.993 | bin: MI(X;M)=3.102, MI(Y;M)=2.086
# Doing rawdata/tanh_1024-20-20-20/epoch00000018
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.639, MI(Y;M)=3.023 | lower: MI(X;M)=6.472, MI(Y;M)=2.574 | bin: MI(X;M)=12.760, MI(Y;M)=3.271
# - Layer 2 upper: MI(X;M)=9.334, MI(Y;M)=2.902 | lower: MI(X;M)=5.848, MI(Y;M)=2.566 | bin: MI(X;M)=12.227, MI(Y;M)=3.217
# - Layer 3 upper: MI(X;M)=8.540, MI(Y;M)=2.828 | lower: MI(X;M)=5.527, MI(Y;M)=2.548 | bin: MI(X;M)=11.407, MI(Y;M)=3.133
# - Layer 4 upper: MI(X;M)=3.080, MI(Y;M)=2.260 | lower: MI(X;M)=1.290, MI(Y;M)=1.021 | bin: MI(X;M)=3.136, MI(Y;M)=2.108
# Doing rawdata/tanh_1024-20-20-20/epoch00000019
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.658, MI(Y;M)=3.030 | lower: MI(X;M)=6.494, MI(Y;M)=2.582 | bin: MI(X;M)=12.744, MI(Y;M)=3.275
# - Layer 2 upper: MI(X;M)=9.361, MI(Y;M)=2.911 | lower: MI(X;M)=5.873, MI(Y;M)=2.575 | bin: MI(X;M)=12.222, MI(Y;M)=3.220
# - Layer 3 upper: MI(X;M)=8.581, MI(Y;M)=2.839 | lower: MI(X;M)=5.562, MI(Y;M)=2.559 | bin: MI(X;M)=11.430, MI(Y;M)=3.144
# - Layer 4 upper: MI(X;M)=3.116, MI(Y;M)=2.284 | lower: MI(X;M)=1.325, MI(Y;M)=1.051 | bin: MI(X;M)=3.183, MI(Y;M)=2.139
# Doing rawdata/tanh_1024-20-20-20/epoch00000020
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.682, MI(Y;M)=3.036 | lower: MI(X;M)=6.515, MI(Y;M)=2.589 | bin: MI(X;M)=12.760, MI(Y;M)=3.277
# - Layer 2 upper: MI(X;M)=9.392, MI(Y;M)=2.917 | lower: MI(X;M)=5.896, MI(Y;M)=2.583 | bin: MI(X;M)=12.225, MI(Y;M)=3.229
# - Layer 3 upper: MI(X;M)=8.610, MI(Y;M)=2.846 | lower: MI(X;M)=5.585, MI(Y;M)=2.568 | bin: MI(X;M)=11.454, MI(Y;M)=3.148
# - Layer 4 upper: MI(X;M)=3.143, MI(Y;M)=2.303 | lower: MI(X;M)=1.354, MI(Y;M)=1.075 | bin: MI(X;M)=3.201, MI(Y;M)=2.156
# Doing rawdata/tanh_1024-20-20-20/epoch00000025
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.773, MI(Y;M)=3.060 | lower: MI(X;M)=6.607, MI(Y;M)=2.617 | bin: MI(X;M)=12.769, MI(Y;M)=3.282
# - Layer 2 upper: MI(X;M)=9.505, MI(Y;M)=2.945 | lower: MI(X;M)=5.991, MI(Y;M)=2.615 | bin: MI(X;M)=12.300, MI(Y;M)=3.236
# - Layer 3 upper: MI(X;M)=8.750, MI(Y;M)=2.881 | lower: MI(X;M)=5.701, MI(Y;M)=2.606 | bin: MI(X;M)=11.543, MI(Y;M)=3.173
# - Layer 4 upper: MI(X;M)=3.264, MI(Y;M)=2.379 | lower: MI(X;M)=1.484, MI(Y;M)=1.184 | bin: MI(X;M)=3.320, MI(Y;M)=2.245
# Doing rawdata/tanh_1024-20-20-20/epoch00000030
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.850, MI(Y;M)=3.076 | lower: MI(X;M)=6.681, MI(Y;M)=2.638 | bin: MI(X;M)=12.783, MI(Y;M)=3.286
# - Layer 2 upper: MI(X;M)=9.592, MI(Y;M)=2.964 | lower: MI(X;M)=6.058, MI(Y;M)=2.637 | bin: MI(X;M)=12.320, MI(Y;M)=3.248
# - Layer 3 upper: MI(X;M)=8.852, MI(Y;M)=2.902 | lower: MI(X;M)=5.782, MI(Y;M)=2.631 | bin: MI(X;M)=11.629, MI(Y;M)=3.178
# - Layer 4 upper: MI(X;M)=3.337, MI(Y;M)=2.424 | lower: MI(X;M)=1.573, MI(Y;M)=1.258 | bin: MI(X;M)=3.379, MI(Y;M)=2.303
# Doing rawdata/tanh_1024-20-20-20/epoch00000035
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.920, MI(Y;M)=3.092 | lower: MI(X;M)=6.749, MI(Y;M)=2.654 | bin: MI(X;M)=12.809, MI(Y;M)=3.288
# - Layer 2 upper: MI(X;M)=9.672, MI(Y;M)=2.981 | lower: MI(X;M)=6.119, MI(Y;M)=2.655 | bin: MI(X;M)=12.348, MI(Y;M)=3.255
# - Layer 3 upper: MI(X;M)=8.948, MI(Y;M)=2.923 | lower: MI(X;M)=5.859, MI(Y;M)=2.652 | bin: MI(X;M)=11.692, MI(Y;M)=3.199
# - Layer 4 upper: MI(X;M)=3.394, MI(Y;M)=2.458 | lower: MI(X;M)=1.649, MI(Y;M)=1.321 | bin: MI(X;M)=3.406, MI(Y;M)=2.333
# Doing rawdata/tanh_1024-20-20-20/epoch00000040
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=10.992, MI(Y;M)=3.105 | lower: MI(X;M)=6.814, MI(Y;M)=2.669 | bin: MI(X;M)=12.839, MI(Y;M)=3.292
# - Layer 2 upper: MI(X;M)=9.749, MI(Y;M)=2.995 | lower: MI(X;M)=6.176, MI(Y;M)=2.671 | bin: MI(X;M)=12.366, MI(Y;M)=3.257
# - Layer 3 upper: MI(X;M)=9.028, MI(Y;M)=2.938 | lower: MI(X;M)=5.923, MI(Y;M)=2.670 | bin: MI(X;M)=11.727, MI(Y;M)=3.207
# - Layer 4 upper: MI(X;M)=3.433, MI(Y;M)=2.483 | lower: MI(X;M)=1.705, MI(Y;M)=1.368 | bin: MI(X;M)=3.422, MI(Y;M)=2.353
# Doing rawdata/tanh_1024-20-20-20/epoch00000045
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.048, MI(Y;M)=3.115 | lower: MI(X;M)=6.869, MI(Y;M)=2.680 | bin: MI(X;M)=12.838, MI(Y;M)=3.292
# - Layer 2 upper: MI(X;M)=9.807, MI(Y;M)=3.006 | lower: MI(X;M)=6.219, MI(Y;M)=2.683 | bin: MI(X;M)=12.386, MI(Y;M)=3.262
# - Layer 3 upper: MI(X;M)=9.091, MI(Y;M)=2.952 | lower: MI(X;M)=5.975, MI(Y;M)=2.684 | bin: MI(X;M)=11.766, MI(Y;M)=3.210
# - Layer 4 upper: MI(X;M)=3.464, MI(Y;M)=2.502 | lower: MI(X;M)=1.752, MI(Y;M)=1.406 | bin: MI(X;M)=3.431, MI(Y;M)=2.374
# Doing rawdata/tanh_1024-20-20-20/epoch00000050
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.103, MI(Y;M)=3.125 | lower: MI(X;M)=6.916, MI(Y;M)=2.690 | bin: MI(X;M)=12.853, MI(Y;M)=3.300
# - Layer 2 upper: MI(X;M)=9.869, MI(Y;M)=3.017 | lower: MI(X;M)=6.262, MI(Y;M)=2.694 | bin: MI(X;M)=12.411, MI(Y;M)=3.268
# - Layer 3 upper: MI(X;M)=9.164, MI(Y;M)=2.966 | lower: MI(X;M)=6.031, MI(Y;M)=2.697 | bin: MI(X;M)=11.820, MI(Y;M)=3.216
# - Layer 4 upper: MI(X;M)=3.486, MI(Y;M)=2.519 | lower: MI(X;M)=1.789, MI(Y;M)=1.439 | bin: MI(X;M)=3.441, MI(Y;M)=2.390
# Doing rawdata/tanh_1024-20-20-20/epoch00000055
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.158, MI(Y;M)=3.133 | lower: MI(X;M)=6.963, MI(Y;M)=2.698 | bin: MI(X;M)=12.884, MI(Y;M)=3.300
# - Layer 2 upper: MI(X;M)=9.926, MI(Y;M)=3.026 | lower: MI(X;M)=6.299, MI(Y;M)=2.704 | bin: MI(X;M)=12.449, MI(Y;M)=3.271
# - Layer 3 upper: MI(X;M)=9.216, MI(Y;M)=2.977 | lower: MI(X;M)=6.071, MI(Y;M)=2.709 | bin: MI(X;M)=11.833, MI(Y;M)=3.226
# - Layer 4 upper: MI(X;M)=3.505, MI(Y;M)=2.534 | lower: MI(X;M)=1.819, MI(Y;M)=1.465 | bin: MI(X;M)=3.446, MI(Y;M)=2.403
# Doing rawdata/tanh_1024-20-20-20/epoch00000060
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.201, MI(Y;M)=3.141 | lower: MI(X;M)=6.999, MI(Y;M)=2.705 | bin: MI(X;M)=12.903, MI(Y;M)=3.302
# - Layer 2 upper: MI(X;M)=9.974, MI(Y;M)=3.035 | lower: MI(X;M)=6.329, MI(Y;M)=2.711 | bin: MI(X;M)=12.463, MI(Y;M)=3.273
# - Layer 3 upper: MI(X;M)=9.266, MI(Y;M)=2.988 | lower: MI(X;M)=6.109, MI(Y;M)=2.719 | bin: MI(X;M)=11.852, MI(Y;M)=3.233
# - Layer 4 upper: MI(X;M)=3.519, MI(Y;M)=2.547 | lower: MI(X;M)=1.845, MI(Y;M)=1.488 | bin: MI(X;M)=3.448, MI(Y;M)=2.419
# Doing rawdata/tanh_1024-20-20-20/epoch00000065
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.239, MI(Y;M)=3.145 | lower: MI(X;M)=7.034, MI(Y;M)=2.711 | bin: MI(X;M)=12.914, MI(Y;M)=3.305
# - Layer 2 upper: MI(X;M)=10.009, MI(Y;M)=3.039 | lower: MI(X;M)=6.352, MI(Y;M)=2.717 | bin: MI(X;M)=12.474, MI(Y;M)=3.275
# - Layer 3 upper: MI(X;M)=9.304, MI(Y;M)=2.995 | lower: MI(X;M)=6.137, MI(Y;M)=2.726 | bin: MI(X;M)=11.847, MI(Y;M)=3.232
# - Layer 4 upper: MI(X;M)=3.529, MI(Y;M)=2.555 | lower: MI(X;M)=1.866, MI(Y;M)=1.507 | bin: MI(X;M)=3.449, MI(Y;M)=2.423
# Doing rawdata/tanh_1024-20-20-20/epoch00000070
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.285, MI(Y;M)=3.152 | lower: MI(X;M)=7.071, MI(Y;M)=2.716 | bin: MI(X;M)=12.936, MI(Y;M)=3.308
# - Layer 2 upper: MI(X;M)=10.057, MI(Y;M)=3.047 | lower: MI(X;M)=6.381, MI(Y;M)=2.724 | bin: MI(X;M)=12.505, MI(Y;M)=3.280
# - Layer 3 upper: MI(X;M)=9.347, MI(Y;M)=3.003 | lower: MI(X;M)=6.169, MI(Y;M)=2.735 | bin: MI(X;M)=11.837, MI(Y;M)=3.237
# - Layer 4 upper: MI(X;M)=3.539, MI(Y;M)=2.566 | lower: MI(X;M)=1.883, MI(Y;M)=1.523 | bin: MI(X;M)=3.451, MI(Y;M)=2.438
# Doing rawdata/tanh_1024-20-20-20/epoch00000075
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.322, MI(Y;M)=3.157 | lower: MI(X;M)=7.102, MI(Y;M)=2.721 | bin: MI(X;M)=12.956, MI(Y;M)=3.308
# - Layer 2 upper: MI(X;M)=10.090, MI(Y;M)=3.052 | lower: MI(X;M)=6.399, MI(Y;M)=2.729 | bin: MI(X;M)=12.526, MI(Y;M)=3.282
# - Layer 3 upper: MI(X;M)=9.378, MI(Y;M)=3.011 | lower: MI(X;M)=6.190, MI(Y;M)=2.742 | bin: MI(X;M)=11.835, MI(Y;M)=3.244
# - Layer 4 upper: MI(X;M)=3.548, MI(Y;M)=2.574 | lower: MI(X;M)=1.902, MI(Y;M)=1.540 | bin: MI(X;M)=3.450, MI(Y;M)=2.449
# Doing rawdata/tanh_1024-20-20-20/epoch00000080
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.362, MI(Y;M)=3.164 | lower: MI(X;M)=7.143, MI(Y;M)=2.727 | bin: MI(X;M)=12.952, MI(Y;M)=3.309
# - Layer 2 upper: MI(X;M)=10.132, MI(Y;M)=3.061 | lower: MI(X;M)=6.429, MI(Y;M)=2.735 | bin: MI(X;M)=12.548, MI(Y;M)=3.284
# - Layer 3 upper: MI(X;M)=9.420, MI(Y;M)=3.022 | lower: MI(X;M)=6.225, MI(Y;M)=2.749 | bin: MI(X;M)=11.859, MI(Y;M)=3.254
# - Layer 4 upper: MI(X;M)=3.557, MI(Y;M)=2.580 | lower: MI(X;M)=1.926, MI(Y;M)=1.561 | bin: MI(X;M)=3.446, MI(Y;M)=2.450
# Doing rawdata/tanh_1024-20-20-20/epoch00000085
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.383, MI(Y;M)=3.166 | lower: MI(X;M)=7.165, MI(Y;M)=2.730 | bin: MI(X;M)=12.967, MI(Y;M)=3.310
# - Layer 2 upper: MI(X;M)=10.151, MI(Y;M)=3.062 | lower: MI(X;M)=6.439, MI(Y;M)=2.739 | bin: MI(X;M)=12.555, MI(Y;M)=3.285
# - Layer 3 upper: MI(X;M)=9.440, MI(Y;M)=3.023 | lower: MI(X;M)=6.238, MI(Y;M)=2.754 | bin: MI(X;M)=11.867, MI(Y;M)=3.255
# - Layer 4 upper: MI(X;M)=3.563, MI(Y;M)=2.586 | lower: MI(X;M)=1.933, MI(Y;M)=1.568 | bin: MI(X;M)=3.449, MI(Y;M)=2.462
# Doing rawdata/tanh_1024-20-20-20/epoch00000090
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.402, MI(Y;M)=3.168 | lower: MI(X;M)=7.179, MI(Y;M)=2.731 | bin: MI(X;M)=12.975, MI(Y;M)=3.309
# - Layer 2 upper: MI(X;M)=10.174, MI(Y;M)=3.065 | lower: MI(X;M)=6.450, MI(Y;M)=2.742 | bin: MI(X;M)=12.544, MI(Y;M)=3.287
# - Layer 3 upper: MI(X;M)=9.466, MI(Y;M)=3.027 | lower: MI(X;M)=6.255, MI(Y;M)=2.759 | bin: MI(X;M)=11.851, MI(Y;M)=3.251
# - Layer 4 upper: MI(X;M)=3.566, MI(Y;M)=2.595 | lower: MI(X;M)=1.940, MI(Y;M)=1.576 | bin: MI(X;M)=3.453, MI(Y;M)=2.469
# Doing rawdata/tanh_1024-20-20-20/epoch00000095
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.442, MI(Y;M)=3.173 | lower: MI(X;M)=7.211, MI(Y;M)=2.734 | bin: MI(X;M)=13.001, MI(Y;M)=3.311
# - Layer 2 upper: MI(X;M)=10.211, MI(Y;M)=3.070 | lower: MI(X;M)=6.469, MI(Y;M)=2.746 | bin: MI(X;M)=12.572, MI(Y;M)=3.287
# - Layer 3 upper: MI(X;M)=9.497, MI(Y;M)=3.034 | lower: MI(X;M)=6.277, MI(Y;M)=2.765 | bin: MI(X;M)=11.844, MI(Y;M)=3.254
# - Layer 4 upper: MI(X;M)=3.572, MI(Y;M)=2.604 | lower: MI(X;M)=1.953, MI(Y;M)=1.590 | bin: MI(X;M)=3.451, MI(Y;M)=2.477
# Doing rawdata/tanh_1024-20-20-20/epoch00000100
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.464, MI(Y;M)=3.176 | lower: MI(X;M)=7.234, MI(Y;M)=2.737 | bin: MI(X;M)=12.997, MI(Y;M)=3.310
# - Layer 2 upper: MI(X;M)=10.237, MI(Y;M)=3.074 | lower: MI(X;M)=6.487, MI(Y;M)=2.750 | bin: MI(X;M)=12.558, MI(Y;M)=3.285
# - Layer 3 upper: MI(X;M)=9.525, MI(Y;M)=3.039 | lower: MI(X;M)=6.299, MI(Y;M)=2.769 | bin: MI(X;M)=11.838, MI(Y;M)=3.256
# - Layer 4 upper: MI(X;M)=3.577, MI(Y;M)=2.609 | lower: MI(X;M)=1.966, MI(Y;M)=1.601 | bin: MI(X;M)=3.450, MI(Y;M)=2.478
# Doing rawdata/tanh_1024-20-20-20/epoch00000110
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.494, MI(Y;M)=3.179 | lower: MI(X;M)=7.270, MI(Y;M)=2.741 | bin: MI(X;M)=12.993, MI(Y;M)=3.310
# - Layer 2 upper: MI(X;M)=10.269, MI(Y;M)=3.079 | lower: MI(X;M)=6.506, MI(Y;M)=2.755 | bin: MI(X;M)=12.572, MI(Y;M)=3.287
# - Layer 3 upper: MI(X;M)=9.558, MI(Y;M)=3.045 | lower: MI(X;M)=6.322, MI(Y;M)=2.777 | bin: MI(X;M)=11.839, MI(Y;M)=3.255
# - Layer 4 upper: MI(X;M)=3.583, MI(Y;M)=2.617 | lower: MI(X;M)=1.982, MI(Y;M)=1.617 | bin: MI(X;M)=3.450, MI(Y;M)=2.490
# Doing rawdata/tanh_1024-20-20-20/epoch00000120
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.533, MI(Y;M)=3.184 | lower: MI(X;M)=7.304, MI(Y;M)=2.743 | bin: MI(X;M)=13.011, MI(Y;M)=3.311
# - Layer 2 upper: MI(X;M)=10.312, MI(Y;M)=3.086 | lower: MI(X;M)=6.527, MI(Y;M)=2.760 | bin: MI(X;M)=12.595, MI(Y;M)=3.292
# - Layer 3 upper: MI(X;M)=9.607, MI(Y;M)=3.056 | lower: MI(X;M)=6.358, MI(Y;M)=2.785 | bin: MI(X;M)=11.822, MI(Y;M)=3.261
# - Layer 4 upper: MI(X;M)=3.590, MI(Y;M)=2.627 | lower: MI(X;M)=2.000, MI(Y;M)=1.634 | bin: MI(X;M)=3.449, MI(Y;M)=2.497
# Doing rawdata/tanh_1024-20-20-20/epoch00000130
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.571, MI(Y;M)=3.188 | lower: MI(X;M)=7.337, MI(Y;M)=2.746 | bin: MI(X;M)=13.029, MI(Y;M)=3.313
# - Layer 2 upper: MI(X;M)=10.341, MI(Y;M)=3.089 | lower: MI(X;M)=6.537, MI(Y;M)=2.765 | bin: MI(X;M)=12.635, MI(Y;M)=3.294
# - Layer 3 upper: MI(X;M)=9.628, MI(Y;M)=3.062 | lower: MI(X;M)=6.371, MI(Y;M)=2.792 | bin: MI(X;M)=11.790, MI(Y;M)=3.263
# - Layer 4 upper: MI(X;M)=3.594, MI(Y;M)=2.636 | lower: MI(X;M)=2.012, MI(Y;M)=1.648 | bin: MI(X;M)=3.448, MI(Y;M)=2.505
# Doing rawdata/tanh_1024-20-20-20/epoch00000140
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.591, MI(Y;M)=3.191 | lower: MI(X;M)=7.360, MI(Y;M)=2.747 | bin: MI(X;M)=13.038, MI(Y;M)=3.314
# - Layer 2 upper: MI(X;M)=10.368, MI(Y;M)=3.093 | lower: MI(X;M)=6.550, MI(Y;M)=2.768 | bin: MI(X;M)=12.647, MI(Y;M)=3.298
# - Layer 3 upper: MI(X;M)=9.655, MI(Y;M)=3.066 | lower: MI(X;M)=6.390, MI(Y;M)=2.798 | bin: MI(X;M)=11.803, MI(Y;M)=3.265
# - Layer 4 upper: MI(X;M)=3.597, MI(Y;M)=2.644 | lower: MI(X;M)=2.025, MI(Y;M)=1.661 | bin: MI(X;M)=3.448, MI(Y;M)=2.515
# Doing rawdata/tanh_1024-20-20-20/epoch00000150
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.621, MI(Y;M)=3.193 | lower: MI(X;M)=7.386, MI(Y;M)=2.749 | bin: MI(X;M)=13.049, MI(Y;M)=3.313
# - Layer 2 upper: MI(X;M)=10.394, MI(Y;M)=3.096 | lower: MI(X;M)=6.563, MI(Y;M)=2.772 | bin: MI(X;M)=12.663, MI(Y;M)=3.294
# - Layer 3 upper: MI(X;M)=9.673, MI(Y;M)=3.070 | lower: MI(X;M)=6.405, MI(Y;M)=2.804 | bin: MI(X;M)=11.761, MI(Y;M)=3.262
# - Layer 4 upper: MI(X;M)=3.601, MI(Y;M)=2.652 | lower: MI(X;M)=2.030, MI(Y;M)=1.669 | bin: MI(X;M)=3.449, MI(Y;M)=2.529
# Doing rawdata/tanh_1024-20-20-20/epoch00000160
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.639, MI(Y;M)=3.195 | lower: MI(X;M)=7.404, MI(Y;M)=2.750 | bin: MI(X;M)=13.056, MI(Y;M)=3.312
# - Layer 2 upper: MI(X;M)=10.406, MI(Y;M)=3.096 | lower: MI(X;M)=6.565, MI(Y;M)=2.774 | bin: MI(X;M)=12.674, MI(Y;M)=3.295
# - Layer 3 upper: MI(X;M)=9.681, MI(Y;M)=3.071 | lower: MI(X;M)=6.408, MI(Y;M)=2.807 | bin: MI(X;M)=11.772, MI(Y;M)=3.260
# - Layer 4 upper: MI(X;M)=3.603, MI(Y;M)=2.657 | lower: MI(X;M)=2.043, MI(Y;M)=1.680 | bin: MI(X;M)=3.448, MI(Y;M)=2.530
# Doing rawdata/tanh_1024-20-20-20/epoch00000170
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.669, MI(Y;M)=3.198 | lower: MI(X;M)=7.431, MI(Y;M)=2.752 | bin: MI(X;M)=13.065, MI(Y;M)=3.315
# - Layer 2 upper: MI(X;M)=10.439, MI(Y;M)=3.102 | lower: MI(X;M)=6.577, MI(Y;M)=2.777 | bin: MI(X;M)=12.684, MI(Y;M)=3.301
# - Layer 3 upper: MI(X;M)=9.715, MI(Y;M)=3.081 | lower: MI(X;M)=6.432, MI(Y;M)=2.813 | bin: MI(X;M)=11.785, MI(Y;M)=3.272
# - Layer 4 upper: MI(X;M)=3.603, MI(Y;M)=2.661 | lower: MI(X;M)=2.058, MI(Y;M)=1.696 | bin: MI(X;M)=3.441, MI(Y;M)=2.541
# Doing rawdata/tanh_1024-20-20-20/epoch00000180
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.682, MI(Y;M)=3.199 | lower: MI(X;M)=7.438, MI(Y;M)=2.750 | bin: MI(X;M)=13.052, MI(Y;M)=3.313
# - Layer 2 upper: MI(X;M)=10.462, MI(Y;M)=3.103 | lower: MI(X;M)=6.581, MI(Y;M)=2.778 | bin: MI(X;M)=12.703, MI(Y;M)=3.299
# - Layer 3 upper: MI(X;M)=9.728, MI(Y;M)=3.081 | lower: MI(X;M)=6.439, MI(Y;M)=2.816 | bin: MI(X;M)=11.767, MI(Y;M)=3.269
# - Layer 4 upper: MI(X;M)=3.606, MI(Y;M)=2.670 | lower: MI(X;M)=2.057, MI(Y;M)=1.699 | bin: MI(X;M)=3.445, MI(Y;M)=2.555
# Doing rawdata/tanh_1024-20-20-20/epoch00000190
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.694, MI(Y;M)=3.199 | lower: MI(X;M)=7.460, MI(Y;M)=2.751 | bin: MI(X;M)=13.057, MI(Y;M)=3.313
# - Layer 2 upper: MI(X;M)=10.481, MI(Y;M)=3.107 | lower: MI(X;M)=6.596, MI(Y;M)=2.782 | bin: MI(X;M)=12.703, MI(Y;M)=3.301
# - Layer 3 upper: MI(X;M)=9.753, MI(Y;M)=3.087 | lower: MI(X;M)=6.459, MI(Y;M)=2.822 | bin: MI(X;M)=11.783, MI(Y;M)=3.273
# - Layer 4 upper: MI(X;M)=3.607, MI(Y;M)=2.674 | lower: MI(X;M)=2.071, MI(Y;M)=1.711 | bin: MI(X;M)=3.444, MI(Y;M)=2.560
# Doing rawdata/tanh_1024-20-20-20/epoch00000200
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.709, MI(Y;M)=3.202 | lower: MI(X;M)=7.475, MI(Y;M)=2.751 | bin: MI(X;M)=13.053, MI(Y;M)=3.312
# - Layer 2 upper: MI(X;M)=10.501, MI(Y;M)=3.110 | lower: MI(X;M)=6.604, MI(Y;M)=2.783 | bin: MI(X;M)=12.701, MI(Y;M)=3.299
# - Layer 3 upper: MI(X;M)=9.763, MI(Y;M)=3.091 | lower: MI(X;M)=6.467, MI(Y;M)=2.825 | bin: MI(X;M)=11.785, MI(Y;M)=3.276
# - Layer 4 upper: MI(X;M)=3.607, MI(Y;M)=2.679 | lower: MI(X;M)=2.080, MI(Y;M)=1.721 | bin: MI(X;M)=3.442, MI(Y;M)=2.562
# Doing rawdata/tanh_1024-20-20-20/epoch00000300
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.856, MI(Y;M)=3.208 | lower: MI(X;M)=7.572, MI(Y;M)=2.741 | bin: MI(X;M)=13.101, MI(Y;M)=3.314
# - Layer 2 upper: MI(X;M)=10.689, MI(Y;M)=3.130 | lower: MI(X;M)=6.651, MI(Y;M)=2.794 | bin: MI(X;M)=12.828, MI(Y;M)=3.304
# - Layer 3 upper: MI(X;M)=9.958, MI(Y;M)=3.121 | lower: MI(X;M)=6.581, MI(Y;M)=2.854 | bin: MI(X;M)=11.837, MI(Y;M)=3.283
# - Layer 4 upper: MI(X;M)=3.613, MI(Y;M)=2.707 | lower: MI(X;M)=2.135, MI(Y;M)=1.779 | bin: MI(X;M)=3.433, MI(Y;M)=2.595
# Doing rawdata/tanh_1024-20-20-20/epoch00000400
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=11.954, MI(Y;M)=3.210 | lower: MI(X;M)=7.640, MI(Y;M)=2.729 | bin: MI(X;M)=13.136, MI(Y;M)=3.314
# - Layer 2 upper: MI(X;M)=10.805, MI(Y;M)=3.139 | lower: MI(X;M)=6.680, MI(Y;M)=2.798 | bin: MI(X;M)=12.885, MI(Y;M)=3.308
# - Layer 3 upper: MI(X;M)=10.095, MI(Y;M)=3.136 | lower: MI(X;M)=6.672, MI(Y;M)=2.870 | bin: MI(X;M)=11.885, MI(Y;M)=3.289
# - Layer 4 upper: MI(X;M)=3.616, MI(Y;M)=2.714 | lower: MI(X;M)=2.168, MI(Y;M)=1.807 | bin: MI(X;M)=3.427, MI(Y;M)=2.608
# Doing rawdata/tanh_1024-20-20-20/epoch00000500
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=12.036, MI(Y;M)=3.212 | lower: MI(X;M)=7.696, MI(Y;M)=2.718 | bin: MI(X;M)=13.146, MI(Y;M)=3.317
# - Layer 2 upper: MI(X;M)=10.891, MI(Y;M)=3.147 | lower: MI(X;M)=6.681, MI(Y;M)=2.798 | bin: MI(X;M)=12.934, MI(Y;M)=3.310
# - Layer 3 upper: MI(X;M)=10.181, MI(Y;M)=3.149 | lower: MI(X;M)=6.720, MI(Y;M)=2.880 | bin: MI(X;M)=11.895, MI(Y;M)=3.292
# - Layer 4 upper: MI(X;M)=3.615, MI(Y;M)=2.716 | lower: MI(X;M)=2.188, MI(Y;M)=1.825 | bin: MI(X;M)=3.424, MI(Y;M)=2.604
# Doing rawdata/tanh_1024-20-20-20/epoch00000600
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=12.104, MI(Y;M)=3.214 | lower: MI(X;M)=7.760, MI(Y;M)=2.713 | bin: MI(X;M)=13.154, MI(Y;M)=3.315
# - Layer 2 upper: MI(X;M)=10.967, MI(Y;M)=3.156 | lower: MI(X;M)=6.713, MI(Y;M)=2.802 | bin: MI(X;M)=12.924, MI(Y;M)=3.312
# - Layer 3 upper: MI(X;M)=10.245, MI(Y;M)=3.167 | lower: MI(X;M)=6.783, MI(Y;M)=2.895 | bin: MI(X;M)=11.876, MI(Y;M)=3.293
# - Layer 4 upper: MI(X;M)=3.611, MI(Y;M)=2.725 | lower: MI(X;M)=2.219, MI(Y;M)=1.857 | bin: MI(X;M)=3.414, MI(Y;M)=2.624
# Doing rawdata/tanh_1024-20-20-20/epoch00000700
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=12.184, MI(Y;M)=3.221 | lower: MI(X;M)=7.847, MI(Y;M)=2.712 | bin: MI(X;M)=13.173, MI(Y;M)=3.317
# - Layer 2 upper: MI(X;M)=11.073, MI(Y;M)=3.168 | lower: MI(X;M)=6.784, MI(Y;M)=2.811 | bin: MI(X;M)=12.939, MI(Y;M)=3.313
# - Layer 3 upper: MI(X;M)=10.314, MI(Y;M)=3.181 | lower: MI(X;M)=6.862, MI(Y;M)=2.909 | bin: MI(X;M)=11.870, MI(Y;M)=3.296
# - Layer 4 upper: MI(X;M)=3.605, MI(Y;M)=2.729 | lower: MI(X;M)=2.248, MI(Y;M)=1.882 | bin: MI(X;M)=3.409, MI(Y;M)=2.632
# Doing rawdata/tanh_1024-20-20-20/epoch00000800
# - Layer 0 upper: MI(X;M)=13.287, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=12.222, MI(Y;M)=3.223 | lower: MI(X;M)=7.906, MI(Y;M)=2.711 | bin: MI(X;M)=13.181, MI(Y;M)=3.318
# - Layer 2 upper: MI(X;M)=11.122, MI(Y;M)=3.175 | lower: MI(X;M)=6.817, MI(Y;M)=2.814 | bin: MI(X;M)=12.946, MI(Y;M)=3.314
# - Layer 3 upper: MI(X;M)=10.362, MI(Y;M)=3.191 | lower: MI(X;M)=6.917, MI(Y;M)=2.917 | bin: MI(X;M)=11.870, MI(Y;M)=3.299
# - Layer 4 upper: MI(X;M)=3.602, MI(Y;M)=2.729 | lower: MI(X;M)=2.265, MI(Y;M)=1.896 | bin: MI(X;M)=3.406, MI(Y;M)=2.632
# Doing rawdata/tanh_1024-20-20-20/epoch00000900
# - Layer 0 upper: MI(X;M)=13.288, MI(Y;M)=3.322 | lower: MI(X;M)=13.285, MI(Y;M)=3.322 | bin: MI(X;M)=13.288, MI(Y;M)=3.322
# - Layer 1 upper: MI(X;M)=12.274, MI(Y;M)=3.227 | lower: MI(X;M)=7.965, MI(Y;M)=2.709 | bin: MI(X;M)=13.182, MI(Y;M)=3.317
# - Layer 2 upper: MI(X;M)=11.180, MI(Y;M)=3.181 | lower: MI(X;M)=6.851, MI(Y;M)=2.819 | bin: MI(X;M)=12.948, MI(Y;M)=3.313
# - Layer 3 upper: MI(X;M)=10.321, MI(Y;M)=3.193 | lower: MI(X;M)=6.918, MI(Y;M)=2.924 | bin: MI(X;M)=11.717, MI(Y;M)=3.292
# - Layer 4 upper: MI(X;M)=3.585, MI(Y;M)=2.723 | lower: MI(X;M)=2.274, MI(Y;M)=1.905 | bin: MI(X;M)=3.392, MI(Y;M)=2.623

# %% [markdown]
# Plot overall summaries
# ----
#
# This is more for diagnostic purposes, not for article

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set_style('darkgrid')


#PLOT_LAYERS = [0,1,2,3,4] # [1,2,3]
#PLOT_LAYERS = [0,1,2,3]
#PLOT_LAYERS = [0,1,2,3]
plt.figure(figsize=(8,8))
gs = gridspec.GridSpec(4,2)
for actndx, (activation, vals) in enumerate(measures.items()):
    epochs = sorted(vals.keys())
    if not len(epochs):
        continue
        
    plt.subplot(gs[0,actndx])
    for lndx, layerid in enumerate(PLOT_LAYERS):
        xmvalsU = np.array([vals[epoch]['H_M_upper'][layerid] for epoch in epochs])
        if DO_LOWER:
            xmvalsL = np.array([vals[epoch]['H_M_lower'][layerid] for epoch in epochs])
        plt.plot(epochs, xmvalsU, label='Layer %d'%layerid)
        #plt.errorbar(epochs, (xmvalsL + xmvalsU)/2,xmvalsU - xmvalsL, label='Layer %d'%layerid)
    plt.xscale('log')
    plt.yscale('log')
    plt.title(activation)
    plt.ylabel('H(M)')
    
    plt.subplot(gs[1,actndx])
    for lndx, layerid in enumerate(PLOT_LAYERS):
        #for epoch in epochs:
        #    print('her',epoch, measures[activation][epoch]['MI_XM_upper'])
        xmvalsU = np.array([vals[epoch]['MI_XM_upper'][layerid] for epoch in epochs])
        if DO_LOWER:
            xmvalsL = np.array([vals[epoch]['MI_XM_lower'][layerid] for epoch in epochs])
        plt.plot(epochs, xmvalsU, label='Layer %d'%layerid)
        #plt.errorbar(epochs, (xmvalsL + xmvalsU)/2,xmvalsU - xmvalsL, label='Layer %d'%layerid)
    plt.xscale('log')
    plt.ylabel('I(X;M)')


    plt.subplot(gs[2,actndx])
    for lndx, layerid in enumerate(PLOT_LAYERS):
        ymvalsU = np.array([vals[epoch]['MI_YM_upper'][layerid] for epoch in epochs])
        if DO_LOWER:
            ymvalsL = np.array([vals[epoch]['MI_YM_lower'][layerid] for epoch in epochs])
        plt.plot(epochs, ymvalsU, label='Layer %d'%layerid)
    plt.xscale('log')
    plt.ylabel('MI(Y;M)')

    if DO_BINNED:
        plt.subplot(gs[3,actndx])
        for lndx, layerid in enumerate(PLOT_LAYERS):
            hbinnedvals = np.array([vals[epoch]['MI_XM_bin'][layerid] for epoch in epochs])
            plt.semilogx(epochs, hbinnedvals, label='Layer %d'%layerid)
        plt.xlabel('Epoch')
        #plt.ylabel("H'(M)")
        plt.ylabel("I(X;M)bin")
        #plt.yscale('log')
    
    if actndx == 0:
        plt.legend(loc='lower right')
        
plt.tight_layout()

# %% [markdown]
# Plot Infoplane Visualization
# ----

# %%
max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
sm = plt.cm.ScalarMappable(cmap='gnuplot', norm=plt.Normalize(vmin=0, vmax=COLORBAR_MAX_EPOCHS))
sm._A = []

fig=plt.figure(figsize=(10,5))
for actndx, (activation, vals) in enumerate(measures.items()):
    epochs = sorted(vals.keys())
    if not len(epochs):
        continue
    plt.subplot(1,2,actndx+1)    
    for epoch in epochs:
        c = sm.to_rgba(epoch)
        xmvals = np.array(vals[epoch]['MI_XM_'+infoplane_measure])[PLOT_LAYERS]
        ymvals = np.array(vals[epoch]['MI_YM_'+infoplane_measure])[PLOT_LAYERS]

        plt.plot(xmvals, ymvals, c=c, alpha=0.1, zorder=1)
        plt.scatter(xmvals, ymvals, s=20, facecolors=[c for _ in PLOT_LAYERS], edgecolor='none', zorder=2)
    
    plt.ylim([0, 3.5])
    plt.xlim([0, 14])
    plt.xlabel('I(X;M)')
    plt.ylabel('I(Y;M)')
    plt.title(activation)
    
cbaxes = fig.add_axes([1.0, 0.125, 0.03, 0.8]) 
plt.colorbar(sm, label='Epoch', cax=cbaxes)
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('infoplane_'+ARCH),bbox_inches='tight')
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p27/lib/python2.7/site-packages/matplotlib/figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# Plot SNR curves
# ----

# %%
plt.figure(figsize=(12,5))

gs = gridspec.GridSpec(len(measures), len(PLOT_LAYERS))
saved_data = {}
for actndx, activation in enumerate(measures.keys()):
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        continue
        
    epochs = []
    means = []
    stds = []
    wnorms = []
    trnloss = []
    tstloss = []
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        with open(cur_dir + "/"+epochfile, 'rb') as f:
            d = cPickle.load(f)
            
        epoch = d['epoch']
        epochs.append(epoch)
        wnorms.append(d['data']['weights_norm'])
        means.append(d['data']['gradmean'])
        stds.append(d['data']['gradstd'])
        trnloss.append(d['loss']['trn'])
        tstloss.append(d['loss']['tst'])

    wnorms, means, stds, trnloss, tstloss = map(np.array, [wnorms, means, stds, trnloss, tstloss])
    saved_data[activation] = {'wnorms':wnorms, 'means': means, 'stds': stds, 'trnloss': trnloss, 'tstloss':tstloss}

# %%
    
    for lndx,layerid in enumerate(PLOT_LAYERS):
        plt.subplot(gs[actndx, lndx])
        plt.plot(epochs, means[:,layerid], 'b', label="Mean")
        plt.plot(epochs, stds[:,layerid], 'orange', label="Std")
        plt.plot(epochs, means[:,layerid]/stds[:,layerid], 'red', label="SNR")
        plt.plot(epochs, wnorms[:,layerid], 'g', label="||W||")

        plt.title('%s - Layer %d'%(activation, layerid))
        plt.xlabel('Epoch')
        plt.gca().set_xscale("log", nonposx='clip')
        plt.gca().set_yscale("log", nonposy='clip')
    

plt.legend(loc='lower left', bbox_to_anchor=(1.1, 0.2))
plt.tight_layout()

# if DO_SAVE:
plt.savefig('plots/' + DIR_TEMPLATE % ('snr_'+ARCH), bbox_inches='tight')

# %%
GRID_PLOT_LAYERS = [0,1,2,3] # [1,2,3]
sns.set_style('whitegrid')
max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
H_X = np.log2(10000)
for actndx, (activation, vals) in enumerate(measures.items()):
    fig = plt.figure(figsize=(12,11))
    gs = gridspec.GridSpec(4, len(GRID_PLOT_LAYERS))
    epochs = np.array(sorted(vals.keys()))
    if not len(epochs):
        continue
        
    plt.subplot(gs[0,0])
    plt.title('Loss')
    plt.xlabel('Epoch')
    plt.plot(epochs,saved_data[activation]['trnloss']/np.log(2), label='Train')
    plt.plot(epochs,saved_data[activation]['tstloss']/np.log(2), label='Test')
    plt.ylabel('Cross entropy loss')
    plt.gca().set_xscale("log", nonposx='clip')
    
    plt.legend(loc='upper right', frameon=True)
        
    vals_binned = np.array([vals[epoch]['MI_XM_bin'] for epoch in epochs])
    vals_lower = np.array([vals[epoch]['MI_XM_lower'] for epoch in epochs])
    vals_upper = np.array([vals[epoch]['MI_XM_upper'] for epoch in epochs])
    for layerndx, layerid in enumerate(GRID_PLOT_LAYERS):
        plt.subplot(gs[1,layerndx])
        plt.plot(epochs, epochs*0 + H_X, 'k:', label=r'$H(X)$')
        plt.fill_between(epochs, vals_lower[:,layerid], vals_upper[:,layerid])
        plt.gca().set_xscale("log", nonposx='clip')
        plt.ylim([0, 1.1*H_X])
        plt.title('Layer %d Mutual Info (KDE)'%(layerid+1))
        plt.ylabel(r'$I(X;T)$')
        plt.xlabel('Epoch')
        if layerndx == len(GRID_PLOT_LAYERS)-1:
            plt.legend(loc='lower right', frameon=True)
        
        plt.subplot(gs[2,layerndx])
        plt.plot(epochs, epochs*0 + H_X, 'k:', label=r'$H(X)$')
        plt.plot(epochs, vals_binned[:,layerid])
        plt.gca().set_xscale("log", nonposx='clip')
        plt.ylim([0, 1.1*H_X])
        plt.ylabel(r'$I(X;T)$')
        plt.title('Layer %d Mutual Info (binned)'%(layerid+1))
        plt.xlabel('Epoch')
        if layerndx == len(GRID_PLOT_LAYERS)-1:
            plt.legend(loc='lower right', frameon=True)
        
        plt.subplot(gs[3,layerndx])
        plt.title('Layer %d SNR'%(layerid+1))
        plt.plot(epochs, saved_data[activation]['means'][:,layerid], 'b', label="Mean")
        plt.plot(epochs, saved_data[activation]['stds'][:,layerid], 'orange', label="Std")
        plt.plot(epochs, saved_data[activation]['means'][:,layerid]/saved_data[activation]['stds'][:,layerid], 'red', label="SNR")
        plt.plot(epochs, saved_data[activation]['wnorms'][:,layerid], 'g', label="||W||")

        plt.xlabel('Epoch')
        plt.gca().set_xscale("log", nonposx='clip')
        plt.gca().set_yscale("log", nonposy='clip')
    
    plt.tight_layout()
    plt.legend(loc='lower left', frameon=True)
    
    if DO_SAVE:
        plt.savefig('plots/' + DIR_TEMPLATE % ('gridplot_'+activation) + '.pdf', bbox_inches='tight')
